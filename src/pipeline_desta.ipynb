# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import torch
import torch_geometric
from torch_geometric.loader import DataLoader
from torch_geometric.nn import summary
import xarray as xr
import yaml

import Dataset
import Models
import Loss
from utils import time_func

# %%
print(f"Torch version: {torch.__version__}")
print(f"Cuda available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Cuda device: {torch.cuda.get_device_name()}")
print(f"Cuda version: {torch.version.cuda}")
print(f"Torch geometric version: {torch_geometric.__version__}")
# Out:
# Torch version: 2.0.1+cu117
# Cuda available: False
# Cuda version: 11.7
# Torch geometric version: 2.3.1

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DEVICE
# Out:
# device(type='cpu')

# %% [markdown]
# ## Soft dice coe implementation

# %%
params = yaml.safe_load(open('./config/pipeline.yaml'))

DATA_PATH = params['input_subset_pre_processed']
MESH_PATH = params['input_subset_grid']

TRAIN_PROP = params['train_prop']
VAL_PROP = params['val_prop']
TEST_PROP = params['test_prop']

TRAIN_BATCH_SIZE = params['train_batch_size']
VAL_BATCH_SIZE = params['val_batch_size']
TEST_BATCH_SIZE = params['test_batch_size']

N_FEATURES = params['n_features']
HID_CHANNELS = params['hid_channels']
N_CLASSES = params['n_classes']

FINAL_ACT = None
if params['final_act'] == "sigmoid":
    FINAL_ACT = torch.sigmoid
elif params['final_act'] == "linear":
    FINAL_ACT = torch.nn.Linear(1, 1)

LOSS_OP = None
if params['loss_op'] == "CE":
    class_weights = [0.2, 0.5, 0.3]
    LOSS_OP = Loss.WeightedCrossEntropyLoss(class_weights)

OPTIMIZER = None
if params['optimizer'] == "Adam":
    OPTIMIZER = torch.optim.Adam

LEARN_RATE = params['learn_rate']

PLOT_SHOW = params['plot_show']
PLOT_FOLDER = params['output_images_path']

# TODO use this
PLOT_VERTICAL = params['plot_vertical']

TIMESTAMP = time_func.start_time()

# %% [markdown]
# ### Dataset creation

# %%
timestamp = time_func.start_time()
train_dataset = Dataset.EddyDataset(root=DATA_PATH, mesh_path=MESH_PATH, split='train')
val_dataset = Dataset.EddyDataset(root=DATA_PATH, mesh_path=MESH_PATH, split='val')
test_dataset = Dataset.EddyDataset(root=DATA_PATH, mesh_path=MESH_PATH, split='test')
time_func.stop_time(timestamp, "Datasets creation")
# Out:
#     Shape of node feature matrix: torch.Size([239536, 1])
#     Shape of graph connectivity in COO format: torch.Size([2, 1432160])
#     Shape of labels: torch.Size([239536])
#   ---  Datasets creation  ---  7.583 seconds.

# %%
print(train_dataset.len(), val_dataset.len(), test_dataset.len())
# Out:
# 128 1 32

# %%
#val_dataset[25]

# %% [markdown]
# ### Testing some parameters and orientation of graph edges

# %%
if (TRAIN_PROP+VAL_PROP+TEST_PROP) != 100:
    raise ValueError(f"Sum of train-val-test proportions with value {TRAIN_PROP+VAL_PROP+TEST_PROP} is different from 1")

if FINAL_ACT == None:
    raise ValueError(f"Parameter 'final_act' is invalid with value {params['final_act']}")

if LOSS_OP == None:
    raise ValueError(f"Parameter 'loss_op' is invalid with value {params['loss_op']}")

if OPTIMIZER == None:
    raise ValueError(f"Parameter 'optimizer' is invalid with value {params['optimizer']}")

dummy_graph = train_dataset[0]

if dummy_graph.num_features != N_FEATURES:
    raise ValueError(f"Graph num_features is different from parameter N_FEATURES: ({dummy_graph.num_features} != {N_FEATURES})")

if dummy_graph.is_directed():
    raise ValueError("Graph edges are directed!")

# %% [markdown]
# ### Train-validation-test split

# %%
train_loader = DataLoader(train_dataset, batch_size=TRAIN_BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=VAL_BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=TEST_BATCH_SIZE, shuffle=False)

print(len(train_loader.dataset), len(val_loader.dataset), len(test_loader.dataset))
# Out:
# 128 1 32

# %% [markdown]
# ### Model instantiation

# %%
Model = Models.GUNet

model = Model(
    in_channels = N_FEATURES,
    hidden_channels = HID_CHANNELS,
    out_channels = N_CLASSES,
    num_nodes = dummy_graph.num_nodes,   # TODO can put these in Dataset.py
    final_act = FINAL_ACT
).to(DEVICE)

model
# Out:
# GUNet instantiated!
# 	Middle act: relu
# 	Final act: torch
# GUNet(
#   (unet): GraphUNet(1, 16, 3, depth=3, pool_ratios=[0.008349475652928996, 0.5, 0.5])
# )

# %%
if torch.cuda.is_available():
    #print("torch.cuda.memory_allocated: %fGB"%(torch.cuda.memory_allocated(0)/1024/1024/1024))
    #print("torch.cuda.memory_reserved: %fGB"%(torch.cuda.memory_reserved(0)/1024/1024/1024))
    #print("torch.cuda.max_memory_reserved: %fGB"%(torch.cuda.max_memory_reserved(0)/1024/1024/1024))
    print(torch.cuda.memory_summary())
else:
    print(summary(model, dummy_graph))
# Out:
# /work/ab0995/b382484/conda/pkgs/eddy-tracking/lib/python3.8/site-packages/torch_sparse/matmul.py:97: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at ../aten/src/ATen/SparseCsrTensorImpl.cpp:54.)
#   C = torch.sparse.mm(A, B)
# +-------------------------------+-------------------------------------------------+---------------------------------------------------------+----------+
# | Layer                         | Input Shape                                     | Output Shape                                            | #Param   |
# |-------------------------------+-------------------------------------------------+---------------------------------------------------------+----------|
# | GUNet                         | [239536, 239536]                                | [239536, 3]                                             | 1,491    |
# | ├─(unet)GraphUNet             | [239536, 1], [2, 1432160]                       | [239536, 3]                                             | 1,491    |
# | │    └─(down_convs)ModuleList | --                                              | --                                                      | 848      |
# | │    │    └─(0)GCNConv        | [239536, 1], [2, 1432160], [1432160]            | [239536, 16]                                            | 32       |
# | │    │    └─(1)GCNConv        | [2000, 16], [2, 19746], [19746]                 | [2000, 16]                                              | 272      |
# | │    │    └─(2)GCNConv        | [1000, 16], [2, 12644], [12644]                 | [1000, 16]                                              | 272      |
# | │    │    └─(3)GCNConv        | [500, 16], [2, 9422], [9422]                    | [500, 16]                                               | 272      |
# | │    └─(pools)ModuleList      | --                                              | --                                                      | 48       |
# | │    │    └─(0)TopKPooling    | [239536, 16], [2, 4295280], [4295280], [239536] | [2000, 16], [2, 19746], [19746], [2000], [2000], [2000] | 16       |
# | │    │    └─(1)TopKPooling    | [2000, 16], [2, 46868], [46868], [2000]         | [1000, 16], [2, 12644], [12644], [1000], [1000], [1000] | 16       |
# | │    │    └─(2)TopKPooling    | [1000, 16], [2, 22600], [22600], [1000]         | [500, 16], [2, 9422], [9422], [500], [500], [500]       | 16       |
# | │    └─(up_convs)ModuleList   | --                                              | --                                                      | 595      |
# | │    │    └─(0)GCNConv        | [1000, 16], [2, 12644], [12644]                 | [1000, 16]                                              | 272      |
# | │    │    └─(1)GCNConv        | [2000, 16], [2, 19746], [19746]                 | [2000, 16]                                              | 272      |
# | │    │    └─(2)GCNConv        | [239536, 16], [2, 1432160], [1432160]           | [239536, 3]                                             | 51       |
# +-------------------------------+-------------------------------------------------+---------------------------------------------------------+----------+

# %% [markdown]
# ### Optimizer

# %%
OPTIMIZER = OPTIMIZER(model.parameters(), lr=LEARN_RATE)

# %% [markdown]
# ### Train function

# %%
def train():
    model.train()
    total_loss = 0

    for batch in train_loader:
        batch = batch.to(DEVICE)

        # zero the parameter gradients
        OPTIMIZER.zero_grad()

        # forward + loss
        pred = model(batch)
        print('train pred:', pred)
        loss = LOSS_OP(pred, batch.y)
        print('train loss:', loss)

        # If you try the Soft Dice Score, use this(even if the loss stays constant)
        #loss.requires_grad = True
        #loss = torch.tensor(loss.item(), requires_grad=True)

        total_loss += loss.item() * batch.num_graphs
        
        # backward + optimize
        loss.backward()
        OPTIMIZER.step()

    average_loss = total_loss / len(train_loader.dataset)
    return average_loss

# %% [markdown]
# ### Evaluation function

# %%
@torch.no_grad()
def evaluate(loader):
    model.eval()
    total_loss = 0

    for batch in loader:
        batch = batch.to(DEVICE)

        # forward + loss
        pred = model(batch)
        print('val pred:', pred)
        loss = LOSS_OP(pred, batch.y)
        print('val loss:', loss)

        total_loss += loss.item() * batch.num_graphs
    
    average_loss = total_loss / len(loader.dataset)
    return average_loss

# %% [markdown]
# ### Computation time check

# %%
time_func.stop_time(TIMESTAMP, "Computation before training finished!")
# Out:
#   ---  Computation before training finished!  ---  14.155 seconds.

# %% [markdown]
# ### Epoch training, validation and testing

# %%
timestamp = time_func.start_time()

train_loss = []
valid_loss = []

for epoch in range(50):
    t_loss = train()
    v_loss = evaluate(val_loader)
    print(f'Epoch: {epoch+1:03d}, Train running loss: {t_loss:.4f}, Val running loss: {v_loss:.4f}')
    train_loss.append(t_loss)
    valid_loss.append(v_loss)

time_func.stop_time(timestamp, "Training Complete!")

metric = evaluate(test_loader)
print(f'Metric for test: {metric:.4f}')
# Out:
# train pred: tensor([[0.4843, 0.5103, 0.4978],
#         [0.4361, 0.5421, 0.4910],
#         [0.3848, 0.5765, 0.4836],
#         ...,
#         [0.5000, 0.5000, 0.5000],
#         [0.4996, 0.5005, 0.4999],
#         [0.5000, 0.5000, 0.5000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.1021, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.4761, 0.5125, 0.4938],
#         [0.4739, 0.5138, 0.4933],
#         [0.4738, 0.5138, 0.4933],
#         ...,
#         [0.0000, 1.0000, 1.0000],
#         [0.0000, 1.0000, 1.0000],
#         [0.0000, 1.0000, 0.0000]])
# val loss: tensor(1.1041)
# Epoch: 001, Train running loss: 1.1021, Val running loss: 1.1041
# train pred: tensor([[0.4912, 0.5036, 0.4963],
#         [0.4972, 0.5000, 0.4972],
#         [0.4853, 0.5072, 0.4953],
#         ...,
#         [0.4989, 0.5027, 0.4972],
#         [0.5013, 0.4990, 0.4979],
#         [0.5022, 0.4971, 0.4981]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0996, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.4802, 0.5068, 0.4910],
#         [0.4781, 0.5078, 0.4904],
#         [0.4780, 0.5078, 0.4904],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 1.0000],
#         [0.0000, 1.0000, 0.0000]])
# val loss: tensor(1.1010)
# Epoch: 002, Train running loss: 1.0996, Val running loss: 1.1010
# train pred: tensor([[0.5040, 0.4951, 0.4956],
#         [0.5042, 0.4948, 0.4953],
#         [0.4926, 0.5009, 0.4933],
#         ...,
#         [0.5042, 0.4948, 0.4954],
#         [0.5037, 0.4947, 0.4953],
#         [0.5040, 0.4951, 0.4956]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0970, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.4841, 0.5009, 0.4883],
#         [0.4823, 0.5015, 0.4876],
#         [0.4822, 0.5015, 0.4876],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 1.0000],
#         [0.0000, 1.0000, 0.0000]])
# val loss: tensor(1.0979)
# Epoch: 003, Train running loss: 1.0970, Val running loss: 1.0979
# train pred: tensor([[0.4982, 0.4954, 0.4913],
#         [0.4867, 0.5003, 0.4887],
#         [0.4861, 0.4999, 0.4883],
#         ...,
#         [0.5061, 0.4928, 0.4932],
#         [0.5070, 0.4923, 0.4927],
#         [0.5063, 0.4924, 0.4929]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0945, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.4879, 0.4948, 0.4858],
#         [0.4863, 0.4950, 0.4850],
#         [0.4862, 0.4951, 0.4850],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000]])
# val loss: tensor(1.0949)
# Epoch: 004, Train running loss: 1.0945, Val running loss: 1.0949
# train pred: tensor([[0.5083, 0.4901, 0.4907],
#         [0.5088, 0.4894, 0.4900],
#         [0.4153, 0.5308, 0.4639],
#         ...,
#         [0.5084, 0.4900, 0.4906],
#         [0.5085, 0.4899, 0.4905],
#         [0.5086, 0.4897, 0.4903]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0920, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.4917, 0.4885, 0.4834],
#         [0.4902, 0.4884, 0.4825],
#         [0.4901, 0.4884, 0.4825],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000]])
# val loss: tensor(1.0923)
# Epoch: 005, Train running loss: 1.0920, Val running loss: 1.0923
# train pred: tensor([[0.5105, 0.4876, 0.4882],
#         [0.5106, 0.4874, 0.4881],
#         [0.5107, 0.4873, 0.4880],
#         ...,
#         [0.5112, 0.4924, 0.4892],
#         [0.5113, 0.4942, 0.4893],
#         [0.5108, 0.4871, 0.4879]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0895, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.4953, 0.4822, 0.4810],
#         [0.4940, 0.4817, 0.4801],
#         [0.4940, 0.4817, 0.4801],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000]])
# val loss: tensor(1.0897)
# Epoch: 006, Train running loss: 1.0895, Val running loss: 1.0897
# train pred: tensor([[0.3991, 0.5172, 0.4413],
#         [0.4319, 0.5041, 0.4545],
#         [0.5008, 0.4867, 0.4810],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000],
#         [0.5137, 0.4836, 0.4846]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0870, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.4988, 0.4760, 0.4781],
#         [0.4977, 0.4751, 0.4770],
#         [0.4976, 0.4751, 0.4770],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000]])
# val loss: tensor(1.0872)
# Epoch: 007, Train running loss: 1.0870, Val running loss: 1.0872
# train pred: tensor([[0.5157, 0.4813, 0.4823],
#         [0.5082, 0.4807, 0.4785],
#         [0.5077, 0.4800, 0.4791],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000],
#         [0.5159, 0.4810, 0.4820]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0844, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5022, 0.4699, 0.4753],
#         [0.5013, 0.4686, 0.4740],
#         [0.5013, 0.4686, 0.4740],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000]])
# val loss: tensor(1.0848)
# Epoch: 008, Train running loss: 1.0844, Val running loss: 1.0848
# train pred: tensor([[0.5045, 0.4785, 0.4738],
#         [0.4748, 0.4790, 0.4580],
#         [0.5052, 0.4768, 0.4733],
#         ...,
#         [0.5181, 0.4781, 0.4793],
#         [0.5181, 0.4780, 0.4792],
#         [0.5176, 0.4789, 0.4800]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0817, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5056, 0.4638, 0.4725],
#         [0.5049, 0.4621, 0.4712],
#         [0.5049, 0.4621, 0.4712],
#         ...,
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000]])
# val loss: tensor(1.0823)
# Epoch: 009, Train running loss: 1.0817, Val running loss: 1.0823
# train pred: tensor([[0.4399, 0.4688, 0.4304],
#         [0.4742, 0.4682, 0.4513],
#         [0.5150, 0.4726, 0.4734],
#         ...,
#         [0.5186, 0.4736, 0.4764],
#         [0.5188, 0.4718, 0.4756],
#         [0.0000, 1.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0791, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5087, 0.4578, 0.4697],
#         [0.5082, 0.4557, 0.4683],
#         [0.5081, 0.4557, 0.4682],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0760)
# Epoch: 010, Train running loss: 1.0791, Val running loss: 1.0760
# train pred: tensor([[0.5231, 0.4713, 0.4728],
#         [0.5190, 0.4697, 0.4726],
#         [0.5203, 0.4681, 0.4716],
#         ...,
#         [0.5229, 0.4721, 0.4735],
#         [0.5247, 0.4711, 0.4724],
#         [0.5228, 0.4724, 0.4737]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0758, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5116, 0.4518, 0.4668],
#         [0.5112, 0.4494, 0.4653],
#         [0.5112, 0.4494, 0.4652],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0734)
# Epoch: 011, Train running loss: 1.0758, Val running loss: 1.0734
# train pred: tensor([[0.5248, 0.4692, 0.4707],
#         [0.5252, 0.4686, 0.4702],
#         [0.4947, 0.4513, 0.4474],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.5249, 0.4690, 0.4705]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0730, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5145, 0.4458, 0.4639],
#         [0.5143, 0.4430, 0.4623],
#         [0.5142, 0.4430, 0.4622],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0708)
# Epoch: 012, Train running loss: 1.0730, Val running loss: 1.0708
# train pred: tensor([[0.5272, 0.4660, 0.4676],
#         [0.5290, 0.4632, 0.4651],
#         [0.4730, 0.4288, 0.4214],
#         ...,
#         [0.5283, 0.4643, 0.4661],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0702, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5176, 0.4400, 0.4611],
#         [0.5175, 0.4368, 0.4593],
#         [0.5174, 0.4368, 0.4593],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0680)
# Epoch: 013, Train running loss: 1.0702, Val running loss: 1.0680
# train pred: tensor([[0.5002, 0.4342, 0.4380],
#         [0.5022, 0.4339, 0.4404],
#         [0.5301, 0.4620, 0.4639],
#         ...,
#         [0.5294, 0.4631, 0.4649],
#         [0.5322, 0.4587, 0.4609],
#         [0.5301, 0.4620, 0.4639]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0673, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5208, 0.4342, 0.4582],
#         [0.5208, 0.4306, 0.4563],
#         [0.5208, 0.4306, 0.4563],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0652)
# Epoch: 014, Train running loss: 1.0673, Val running loss: 1.0652
# train pred: tensor([[0.5053, 0.4225, 0.4375],
#         [0.5276, 0.4513, 0.4577],
#         [0.5294, 0.4528, 0.4589],
#         ...,
#         [0.5335, 0.4573, 0.4594],
#         [0.5349, 0.4550, 0.4573],
#         [0.5338, 0.4567, 0.4589]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0643, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5241, 0.4283, 0.4553],
#         [0.5243, 0.4245, 0.4532],
#         [0.5242, 0.4244, 0.4532],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0623)
# Epoch: 015, Train running loss: 1.0643, Val running loss: 1.0623
# train pred: tensor([[0.5254, 0.4373, 0.4483],
#         [0.5098, 0.4108, 0.4313],
#         [0.5360, 0.4538, 0.4563],
#         ...,
#         [0.5353, 0.4549, 0.4573],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0612, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5275, 0.4225, 0.4522],
#         [0.5278, 0.4183, 0.4501],
#         [0.5278, 0.4183, 0.4501],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0594)
# Epoch: 016, Train running loss: 1.0612, Val running loss: 1.0594
# train pred: tensor([[0.5353, 0.4444, 0.4533],
#         [0.5308, 0.4236, 0.4456],
#         [0.5396, 0.4487, 0.4518],
#         ...,
#         [0.5387, 0.4502, 0.4530],
#         [0.5408, 0.4469, 0.4501],
#         [0.5389, 0.4485, 0.4522]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0581, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5311, 0.4167, 0.4491],
#         [0.5315, 0.4121, 0.4469],
#         [0.5315, 0.4121, 0.4468],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0564)
# Epoch: 017, Train running loss: 1.0581, Val running loss: 1.0564
# train pred: tensor([[0.5302, 0.4165, 0.4295],
#         [0.5092, 0.3700, 0.3895],
#         [0.5412, 0.4470, 0.4502],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.5432, 0.4451, 0.4482]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0549, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5349, 0.4108, 0.4460],
#         [0.5354, 0.4059, 0.4436],
#         [0.5354, 0.4058, 0.4435],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0533)
# Epoch: 018, Train running loss: 1.0549, Val running loss: 1.0533
# train pred: tensor([[0.5425, 0.4313, 0.4421],
#         [0.5347, 0.3979, 0.4261],
#         [0.5309, 0.3951, 0.4233],
#         ...,
#         [0.5489, 0.4467, 0.4481],
#         [0.5480, 0.4412, 0.4443],
#         [0.5448, 0.4419, 0.4457]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0517, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5387, 0.4048, 0.4427],
#         [0.5395, 0.3996, 0.4402],
#         [0.5395, 0.3995, 0.4402],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0501)
# Epoch: 019, Train running loss: 1.0517, Val running loss: 1.0501
# train pred: tensor([[0.5474, 0.4386, 0.4429],
#         [0.5504, 0.4175, 0.4305],
#         [0.5294, 0.3563, 0.3924],
#         ...,
#         [0.5501, 0.4342, 0.4391],
#         [0.5491, 0.4359, 0.4406],
#         [0.5508, 0.4339, 0.4385]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0483, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5428, 0.3988, 0.4395],
#         [0.5437, 0.3932, 0.4368],
#         [0.5437, 0.3932, 0.4367],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0468)
# Epoch: 020, Train running loss: 1.0483, Val running loss: 1.0468
# train pred: tensor([[0.5499, 0.4354, 0.4407],
#         [0.5507, 0.4341, 0.4396],
#         [0.5358, 0.3460, 0.3939],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0449, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5469, 0.3927, 0.4361],
#         [0.5480, 0.3868, 0.4333],
#         [0.5480, 0.3867, 0.4333],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0434)
# Epoch: 021, Train running loss: 1.0449, Val running loss: 1.0434
# train pred: tensor([[0.5531, 0.4150, 0.4309],
#         [0.5570, 0.4249, 0.4322],
#         [0.5482, 0.3795, 0.4166],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.5575, 0.4241, 0.4316]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0413, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5511, 0.3867, 0.4326],
#         [0.5525, 0.3803, 0.4297],
#         [0.5525, 0.3802, 0.4297],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0400)
# Epoch: 022, Train running loss: 1.0413, Val running loss: 1.0400
# train pred: tensor([[0.5587, 0.4230, 0.4312],
#         [0.5595, 0.4218, 0.4302],
#         [0.5596, 0.4216, 0.4300],
#         ...,
#         [0.5601, 0.4208, 0.4294],
#         [0.5601, 0.4208, 0.4294],
#         [0.5573, 0.4252, 0.4331]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0377, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5555, 0.3806, 0.4289],
#         [0.5571, 0.3739, 0.4259],
#         [0.5570, 0.3738, 0.4259],
#         ...,
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0364)
# Epoch: 023, Train running loss: 1.0377, Val running loss: 1.0364
# train pred: tensor([[0.5620, 0.4007, 0.4211],
#         [0.5599, 0.3359, 0.3845],
#         [0.5624, 0.3990, 0.4204],
#         ...,
#         [0.5645, 0.4147, 0.4250],
#         [0.5616, 0.4194, 0.4288],
#         [0.5641, 0.4154, 0.4256]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0340, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5599, 0.3746, 0.4250],
#         [0.5618, 0.3675, 0.4219],
#         [0.5617, 0.3673, 0.4218],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0283)
# Epoch: 024, Train running loss: 1.0340, Val running loss: 1.0283
# train pred: tensor([[0.5669, 0.3809, 0.4046],
#         [0.5682, 0.4099, 0.4217],
#         [0.5626, 0.3751, 0.4093],
#         ...,
#         [0.5665, 0.4125, 0.4237],
#         [0.5709, 0.4056, 0.4182],
#         [0.5675, 0.4114, 0.4225]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0296, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5645, 0.3684, 0.4210],
#         [0.5666, 0.3610, 0.4177],
#         [0.5666, 0.3609, 0.4177],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0246)
# Epoch: 025, Train running loss: 1.0296, Val running loss: 1.0246
# train pred: tensor([[0.5687, 0.4101, 0.4223],
#         [0.5745, 0.3881, 0.4118],
#         [0.5657, 0.3406, 0.4066],
#         ...,
#         [0.5724, 0.4043, 0.4177],
#         [0.5717, 0.4054, 0.4186],
#         [0.5723, 0.4134, 0.4190]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0256, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5691, 0.3623, 0.4169],
#         [0.5715, 0.3545, 0.4133],
#         [0.5715, 0.3544, 0.4133],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0207)
# Epoch: 026, Train running loss: 1.0256, Val running loss: 1.0207
# train pred: tensor([[0.5752, 0.4009, 0.4155],
#         [0.5813, 0.3915, 0.4081],
#         [0.5747, 0.3896, 0.4137],
#         ...,
#         [0.5729, 0.4071, 0.4186],
#         [0.5811, 0.3987, 0.4092],
#         [0.5752, 0.4039, 0.4158]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0216, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5739, 0.3560, 0.4126],
#         [0.5766, 0.3479, 0.4089],
#         [0.5766, 0.3478, 0.4089],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0168)
# Epoch: 027, Train running loss: 1.0216, Val running loss: 1.0168
# train pred: tensor([[0.5795, 0.3782, 0.4063],
#         [0.5822, 0.3742, 0.4031],
#         [0.5799, 0.3946, 0.4111],
#         ...,
#         [0.5786, 0.3967, 0.4127],
#         [0.5817, 0.3927, 0.4090],
#         [1.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0175, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5787, 0.3497, 0.4082],
#         [0.5817, 0.3413, 0.4043],
#         [0.5817, 0.3411, 0.4043],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0128)
# Epoch: 028, Train running loss: 1.0175, Val running loss: 1.0128
# train pred: tensor([[0.5842, 0.3892, 0.4072],
#         [0.5872, 0.3846, 0.4038],
#         [0.5831, 0.3909, 0.4086],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [0.5871, 0.3858, 0.4039]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0133, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5837, 0.3432, 0.4037],
#         [0.5869, 0.3345, 0.3995],
#         [0.5869, 0.3344, 0.3995],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0088)
# Epoch: 029, Train running loss: 1.0133, Val running loss: 1.0088
# train pred: tensor([[0.5926, 0.3776, 0.3987],
#         [0.5885, 0.3837, 0.4034],
#         [0.5932, 0.3615, 0.3940],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0090, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5889, 0.3366, 0.3990],
#         [0.5923, 0.3276, 0.3946],
#         [0.5923, 0.3275, 0.3946],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0046)
# Epoch: 030, Train running loss: 1.0090, Val running loss: 1.0046
# train pred: tensor([[0.5989, 0.3331, 0.3770],
#         [0.5913, 0.3806, 0.4013],
#         [0.6039, 0.2902, 0.3631],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0047, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5941, 0.3299, 0.3941],
#         [0.5978, 0.3206, 0.3896],
#         [0.5978, 0.3205, 0.3896],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(1.0004)
# Epoch: 031, Train running loss: 1.0047, Val running loss: 1.0004
# train pred: tensor([[0.5996, 0.3693, 0.3931],
#         [0.6013, 0.3667, 0.3911],
#         [0.6023, 0.3585, 0.3893],
#         ...,
#         [0.5968, 0.3746, 0.3963],
#         [0.6060, 0.3637, 0.3863],
#         [0.6024, 0.3651, 0.3899]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(1.0002, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.5996, 0.3230, 0.3891],
#         [0.6035, 0.3135, 0.3844],
#         [0.6035, 0.3134, 0.3843],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9961)
# Epoch: 032, Train running loss: 1.0002, Val running loss: 0.9961
# train pred: tensor([[0.6359, 0.2036, 0.3073],
#         [0.6173, 0.2729, 0.3494],
#         [0.6034, 0.3648, 0.3898],
#         ...,
#         [0.6050, 0.3624, 0.3881],
#         [0.6062, 0.3609, 0.3868],
#         [1.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9957, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6052, 0.3160, 0.3840],
#         [0.6094, 0.3063, 0.3789],
#         [0.6094, 0.3061, 0.3789],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9918)
# Epoch: 033, Train running loss: 0.9957, Val running loss: 0.9918
# train pred: tensor([[0.6056, 0.3627, 0.3884],
#         [0.6103, 0.3558, 0.3833],
#         [0.6086, 0.3583, 0.3851],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [0.6086, 0.3583, 0.3851]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9912, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6110, 0.3090, 0.3787],
#         [0.6155, 0.2989, 0.3734],
#         [0.6155, 0.2987, 0.3734],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9874)
# Epoch: 034, Train running loss: 0.9912, Val running loss: 0.9874
# train pred: tensor([[0.6161, 0.3486, 0.3780],
#         [0.6189, 0.3445, 0.3750],
#         [0.6147, 0.3312, 0.3770],
#         ...,
#         [0.6176, 0.3464, 0.3764],
#         [0.6190, 0.3444, 0.3749],
#         [0.6158, 0.3490, 0.3783]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9865, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6169, 0.3018, 0.3732],
#         [0.6217, 0.2914, 0.3677],
#         [0.6217, 0.2913, 0.3676],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9829)
# Epoch: 035, Train running loss: 0.9865, Val running loss: 0.9829
# train pred: tensor([[0.6179, 0.3471, 0.3769],
#         [0.6297, 0.2984, 0.3565],
#         [0.6272, 0.3338, 0.3670],
#         ...,
#         [0.6257, 0.3360, 0.3687],
#         [0.6173, 0.3480, 0.3776],
#         [0.6257, 0.3361, 0.3686]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9819, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6230, 0.2946, 0.3676],
#         [0.6281, 0.2839, 0.3618],
#         [0.6281, 0.2838, 0.3618],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9784)
# Epoch: 036, Train running loss: 0.9819, Val running loss: 0.9784
# train pred: tensor([[0.6261, 0.3365, 0.3691],
#         [0.6261, 0.3365, 0.3691],
#         [0.6234, 0.3300, 0.3709],
#         ...,
#         [0.6260, 0.3367, 0.3692],
#         [0.6260, 0.3367, 0.3692],
#         [0.6291, 0.3329, 0.3660]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9772, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6292, 0.2873, 0.3619],
#         [0.6347, 0.2763, 0.3558],
#         [0.6347, 0.2762, 0.3558],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9739)
# Epoch: 037, Train running loss: 0.9772, Val running loss: 0.9739
# train pred: tensor([[0.6618, 0.1930, 0.3015],
#         [0.6923, 0.1447, 0.2591],
#         [0.6308, 0.3161, 0.3623],
#         ...,
#         [0.6377, 0.3214, 0.3578],
#         [0.6319, 0.3301, 0.3639],
#         [0.6308, 0.3311, 0.3650]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9726, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6355, 0.2799, 0.3561],
#         [0.6413, 0.2687, 0.3497],
#         [0.6413, 0.2686, 0.3497],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9694)
# Epoch: 038, Train running loss: 0.9726, Val running loss: 0.9694
# train pred: tensor([[0.6523, 0.2168, 0.3247],
#         [0.6615, 0.2003, 0.3113],
#         [0.6517, 0.2489, 0.3344],
#         ...,
#         [0.6412, 0.3177, 0.3549],
#         [0.6352, 0.3261, 0.3612],
#         [0.6352, 0.3261, 0.3612]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9678, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6420, 0.2726, 0.3502],
#         [0.6481, 0.2611, 0.3435],
#         [0.6481, 0.2610, 0.3435],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9649)
# Epoch: 039, Train running loss: 0.9678, Val running loss: 0.9649
# train pred: tensor([[0.7369, 0.0997, 0.2053],
#         [0.7162, 0.1238, 0.2350],
#         [0.6410, 0.3191, 0.3559],
#         ...,
#         [0.6435, 0.3157, 0.3533],
#         [0.6557, 0.2990, 0.3408],
#         [0.6488, 0.3092, 0.3479]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9631, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6486, 0.2652, 0.3441],
#         [0.6550, 0.2535, 0.3372],
#         [0.6550, 0.2534, 0.3371],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9603)
# Epoch: 040, Train running loss: 0.9631, Val running loss: 0.9603
# train pred: tensor([[0.6478, 0.3109, 0.3496],
#         [0.6566, 0.2989, 0.3406],
#         [0.6660, 0.2862, 0.3309],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [0.6537, 0.3028, 0.3435],
#         [0.6421, 0.3187, 0.3554]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9584, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6552, 0.2578, 0.3380],
#         [0.6620, 0.2459, 0.3307],
#         [0.6620, 0.2458, 0.3307],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9580)
# Epoch: 041, Train running loss: 0.9584, Val running loss: 0.9580
# train pred: tensor([[0.6666, 0.2249, 0.3206],
#         [0.6791, 0.1925, 0.3035],
#         [0.6593, 0.2965, 0.3386],
#         ...,
#         [0.6530, 0.3050, 0.3450],
#         [0.6597, 0.2959, 0.3382],
#         [0.6582, 0.2979, 0.3396]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9538, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6620, 0.2505, 0.3318],
#         [0.6691, 0.2383, 0.3242],
#         [0.6691, 0.2382, 0.3242],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9535)
# Epoch: 042, Train running loss: 0.9538, Val running loss: 0.9535
# train pred: tensor([[0.7334, 0.1165, 0.2294],
#         [0.7084, 0.1654, 0.2671],
#         [0.6650, 0.2900, 0.3334],
#         ...,
#         [0.6619, 0.2940, 0.3365],
#         [0.6742, 0.2787, 0.3242],
#         [0.6560, 0.3020, 0.3425]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9491, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6688, 0.2431, 0.3255],
#         [0.6763, 0.2308, 0.3176],
#         [0.6763, 0.2306, 0.3176],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9490)
# Epoch: 043, Train running loss: 0.9491, Val running loss: 0.9490
# train pred: tensor([[0.6670, 0.2884, 0.3320],
#         [0.6686, 0.2864, 0.3304],
#         [0.6741, 0.2790, 0.3248],
#         ...,
#         [0.6682, 0.2876, 0.3309],
#         [0.6796, 0.2730, 0.3194],
#         [0.6710, 0.2833, 0.3280]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9444, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6758, 0.2358, 0.3191],
#         [0.6836, 0.2233, 0.3110],
#         [0.6836, 0.2231, 0.3109],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9445)
# Epoch: 044, Train running loss: 0.9444, Val running loss: 0.9445
# train pred: tensor([[0.6779, 0.2752, 0.3216],
#         [0.6832, 0.2683, 0.3163],
#         [0.6836, 0.2678, 0.3159],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [0.6733, 0.2812, 0.3262]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9398, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6828, 0.2285, 0.3126],
#         [0.6909, 0.2159, 0.3042],
#         [0.6909, 0.2157, 0.3042],
#         ...,
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9401)
# Epoch: 045, Train running loss: 0.9398, Val running loss: 0.9401
# train pred: tensor([[0.6847, 0.2379, 0.3108],
#         [0.6929, 0.2306, 0.3030],
#         [0.7495, 0.1095, 0.2220],
#         ...,
#         [0.6811, 0.2725, 0.3189],
#         [0.6949, 0.2548, 0.3051],
#         [0.6888, 0.2625, 0.3111]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9350, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6899, 0.2213, 0.3061],
#         [0.6983, 0.2085, 0.2974],
#         [0.6983, 0.2084, 0.2974],
#         ...,
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9356)
# Epoch: 046, Train running loss: 0.9350, Val running loss: 0.9356
# train pred: tensor([[0.7015, 0.2232, 0.2926],
#         [0.6925, 0.2594, 0.3080],
#         [0.6907, 0.2457, 0.3068],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9304, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.6970, 0.2142, 0.2995],
#         [0.7057, 0.2012, 0.2905],
#         [0.7057, 0.2011, 0.2905],
#         ...,
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9312)
# Epoch: 047, Train running loss: 0.9304, Val running loss: 0.9312
# train pred: tensor([[0.6942, 0.2584, 0.3067],
#         [0.6984, 0.2532, 0.3026],
#         [0.6992, 0.2521, 0.3018],
#         ...,
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9258, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.7041, 0.2071, 0.2929],
#         [0.7132, 0.1941, 0.2837],
#         [0.7132, 0.1939, 0.2836],
#         ...,
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9268)
# Epoch: 048, Train running loss: 0.9258, Val running loss: 0.9268
# train pred: tensor([[0.6988, 0.2538, 0.3026],
#         [0.7068, 0.2438, 0.2947],
#         [0.7081, 0.2421, 0.2933],
#         ...,
#         [0.7026, 0.2490, 0.2988],
#         [0.7213, 0.2265, 0.2802],
#         [1.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9213, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.7113, 0.2001, 0.2863],
#         [0.7207, 0.1870, 0.2767],
#         [0.7207, 0.1869, 0.2767],
#         ...,
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9225)
# Epoch: 049, Train running loss: 0.9213, Val running loss: 0.9225
# train pred: tensor([[0.7475, 0.1287, 0.2387],
#         [0.7120, 0.2260, 0.2885],
#         [0.7183, 0.2306, 0.2836],
#         ...,
#         [0.7093, 0.2418, 0.2926],
#         [0.7176, 0.2315, 0.2843],
#         [0.7146, 0.2351, 0.2873]], grad_fn=<SigmoidBackward0>)
# train loss: tensor(0.9167, grad_fn=<NllLossBackward0>)
# val pred: tensor([[0.7185, 0.1933, 0.2796],
#         [0.7281, 0.1801, 0.2698],
#         [0.7282, 0.1799, 0.2697],
#         ...,
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9182)
# Epoch: 050, Train running loss: 0.9167, Val running loss: 0.9182
#   ---  Training Complete!  ---  4903.898 seconds.
# val pred: tensor([[0.7207, 0.1823, 0.2764],
#         [0.7303, 0.1697, 0.2666],
#         [0.7291, 0.1752, 0.2683],
#         ...,
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]])
# val loss: tensor(0.9155)
# Metric for test: 0.9155

# %% [markdown]
# ### Comparison plot for train/validation loss

# %%
plt.figure(figsize=(8, 4))
plt.plot(train_loss, label='Train loss')
plt.plot(valid_loss, label='Validation loss')
plt.legend(title="Loss type: " + str(LOSS_OP))

if PLOT_SHOW:
    plt.show()
else:
    plt.savefig(PLOT_FOLDER+"/train_val_losses.png")
    plt.close()

# %% [markdown]
# ### Graphical comparison model prediction/ground truth

# %%
torch.no_grad()
model.eval()
batch = next(iter(test_loader))
batch = batch.to(DEVICE)
pred = model(batch)
pred
# Out:
# tensor([[0.7207, 0.1823, 0.2764],
#         [0.7303, 0.1697, 0.2666],
#         [0.7291, 0.1752, 0.2683],
#         ...,
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000]], grad_fn=<SigmoidBackward0>)

# %%
mesh = xr.open_dataset(MESH_PATH)
mesh_lon = mesh.lon[mesh.nodes].values
mesh_lat = mesh.lat[mesh.nodes].values

# %%
this_target = batch.y[:mesh.dims['nodes_subset']]
this_pred = []
for p in pred[:mesh.dims['nodes_subset']]:
    p = p.tolist()
    max_value = max(p)
    max_index = p.index(max_value)
    this_pred.append(max_index)

# %%
plt.figure(figsize=(14, 6))
plt.scatter(mesh_lon, mesh_lat, c=this_target, s=1)

plt.figure(figsize=(14, 6))
plt.scatter(mesh_lon, mesh_lat, c=this_pred, s=1)

if PLOT_SHOW:
    plt.show()
else:
    plt.savefig(PLOT_FOLDER+"/pred_vs_ground.png")
    plt.close()

# %% [markdown]
# ### Precision calculation

# %%
torch.no_grad()
model.eval()
correct_pred = 0
tot_pred = 0
tot_background = 0

for batch in test_loader:
    batch = batch.to(DEVICE)
    pred = model(batch)
    tot_pred += len(pred)
    
    pred_values = []
    for p in pred:
        p = p.tolist()
        max_value = max(p)
        max_index = p.index(max_value)
        pred_values.append(max_index)
    
    for b in batch.y:
        if b==0:
            tot_background += 1
    
    # Should always be equal
    print(len(pred_values), len(batch.y))
    for i in range(len(batch.y)):
        if pred_values[i] == batch.y[i]:
            correct_pred += 1

print(f"Correct predictions:\t{correct_pred}")
print(f"Total background cells:\t{tot_background}")
print(f"Total predictions:\t{tot_pred}")
print(f"Graph U-Net accuracy:\t{correct_pred/tot_pred:.4f}")
# Out:
# 7665152 7665152
# Correct predictions:	6664182
# Total background cells:	6664044
# Total predictions:	7665152
# Graph U-Net accuracy:	0.8694
